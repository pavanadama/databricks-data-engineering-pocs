# %% [markdown]
# # POC 02 - Databricks AI Agent / Genie
# The data setup and validation are in this notebook. Genie Agent and AI Playground configuration are completed in the Databricks UI.

# %%
df = spark.table('`databricks-customer-data-poc`.data.customer_orders')
display(df.orderBy('OrderID'))

# %%
display(df.selectExpr('sum(Amount) AS TotalOrderValue'))

# %%
display(df.filter("Status = 'Delayed'").orderBy('OrderID'))

# %% [markdown]
# ## AI Playground integration
# Open AI/ML -> Playground, choose a tools-enabled model, then Tools -> Add tool and select the available Genie Agent/Genie tool. Run the test cases in `test_cases.md`.
